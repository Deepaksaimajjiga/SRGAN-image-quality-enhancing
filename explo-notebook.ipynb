# %%
import keras
import shutil
import tensorflow
import keras
from keras.models import Model,Sequential
from keras.layers import *
import pandas as pd
import numpy as np
from keras.utils import to_categorical
from keras.models import Sequential
from keras.utils import np_utils
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
#import numpy as np
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D
from keras.layers import Dropout, Flatten, GlobalAveragePooling2D
import cv2
import matplotlib.pyplot as plt
from scipy import ndimage
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from sklearn.preprocessing import OneHotEncoder
import numpy as np # linear algebra
import pandas as pd 
from IPython.display import display, Image
from matplotlib.pyplot import imshow
from keras.layers import Conv2D, UpSampling2D, InputLayer 
from keras.models import Sequential
from tensorflow.keras.utils import img_to_array, load_img ,array_to_img
from skimage.color import lab2rgb, rgb2lab
from keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.utils import array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import os
import random
#from keras.layers.advanced_activations import*
from keras.optimizers import Adam
import PIL
from PIL import Image

tf.config.run_functions_eagerly(True)
def residual_layer(model):
  start = model
  forward = Conv2D(64, (3,3), padding='same', strides=1)(model)
  forward = BatchNormalization(momentum = 0.5)(forward)
  forward = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=[1,2])(forward)
  forward = Conv2D(64, (3,3), padding='same', strides=1)(forward)
  forward = BatchNormalization(momentum = 0.5)(forward)
  
  residual = add([start,forward])
  
  return residual


def upsample(model):
  upscale = Conv2D(64, (3,3), padding='same', strides=1)(model)
  upscale = UpSampling2D()(upscale)
  upscale = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=[1,2])(upscale)
  
  return upscale


def generator(res_size, up_size, shape):
  gen_inp = Input(shape = shape)
  model = Conv2D(64, (9,9), padding='same', strides=1)(gen_inp)
  model = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=[1,2])(model)
  
  start_res = model
  
  for i in range(res_size):
    model = residual_layer(model)
    
  model = Conv2D(64, (3,3), padding='same', strides=1)(model)
  model = BatchNormalization(momentum = 0.5)(model)
  
  model = add([start_res,model])
  
  
  for i in range(up_size):
    model = upsample(model)
    
  final = Conv2D(3, (9,9), activation = 'tanh', padding='same', strides=1)(model)
  
  gen = Model(inputs=gen_inp, outputs=final)
  
  #print(model.summary())

  return gen


def dis_layer(model, filters, kernal_size, stride):
  model = Conv2D(filters = filters, kernel_size = kernal_size, padding='same', strides= stride)(model)
  model = BatchNormalization(momentum=0.5)(model)
  model = LeakyReLU(alpha = 0.2)(model)
  
  return model

def discriminator(shape):
  dis_inp = Input(shape = shape)
  model = Conv2D(64, kernel_size = 3, padding='same', strides=1)(dis_inp)
  model = BatchNormalization(momentum=0.5)(model)
  
  model = dis_layer(model, 64, 3, 1)
  model = dis_layer(model, 128, 3, 1)
  model = dis_layer(model, 128, 3, 2)
  model = dis_layer(model, 256, 3, 2)
  model = dis_layer(model, 256, 3, 2)
  model = dis_layer(model, 512, 3, 2)
  model = dis_layer(model, 512, 3, 2)
  
  model = Flatten()(model)
  model = Dense(100)(model)
  model = LeakyReLU(alpha = 0.2)(model)
  model = Dense(1, activation = 'sigmoid')(model)
  dis = Model(inputs=dis_inp, outputs=model)
  return dis

from keras.applications.vgg19 import VGG19
def vgg_loss(true, pred):
  vgg = VGG19(include_top=False, weights='imagenet')
  vgg.trainable = False
  model = Model(inputs = vgg.input, outputs = vgg.get_layer('block5_conv4').output)
  
  model.trainable = False
  
  return K.mean( K.square( model(true) - model(pred) ) )

files = os.listdir('/kaggle/input/explo-deepak/explo/archive/Data/HR')
files1 = os.listdir('/kaggle/input/explo-deepak/explo/archive/Data/LR')
x_hr = np.empty((100,384,384,3), 'float64')
x_lr = np.empty((100,96,96,3), 'float64')
#/kaggle/input/explo-deepak/explo/archive/Data/HR
for i in range(100):
  image = Image.open('/kaggle/input/explo-deepak/explo/archive/Data/HR/'+files[i])
  image1 = image.resize((384,384), resample=PIL.Image.BICUBIC)
  image1 = np.array(image1)
  if image1.shape ==  (384,384):
    image = Image.open('/kaggle/input/explo-deepak/explo/archive/Data/LR/'+files1[i])
    image1 = image.resize((384,384), resample=PIL.Image.BICUBIC)
    image1 = np.array(image1)
    x_hr[i] = image1
    im = image.resize((96,96), resample=PIL.Image.BICUBIC)
    im = np.array(im)
    x_lr[i] = im
  else:
    x_hr[i] = image1
    im = image.resize((96,96), resample=PIL.Image.BICUBIC)
    im = np.array(im)
    x_lr[i] = im
  
  
x_hr = (x_hr - 127.5)/127.5
x_lr = (x_lr - 127.5)/127.5

gen_shape = (96,96,3)
dis_shape = (384,384,3)

adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

generator = generator(16, 2, gen_shape)
print(generator.summary())
discriminator = discriminator(dis_shape)
print(discriminator.summary())
discriminator.compile(loss="binary_crossentropy", optimizer=adam)

discriminator.trainable = False

gan_input = Input(shape = gen_shape)
gen_out = generator(gan_input)
gan_final = discriminator(gen_out) 
gans = Model(inputs=gan_input, outputs=[gen_out,gan_final])
gans.compile(loss=[vgg_loss, "binary_crossentropy"], loss_weights=[1., 1e-3], optimizer=adam)




tt1=[]
tt2=[]
m = x_hr.shape[0]
loss_history = []
batch_size = 4
for epoch in range(10):
    itera  = int(m/batch_size)
    dis_mean = 0
    gan_mean = 0
    for i in range(itera):
      high_resol = x_hr[i*batch_size:min((i+1)*batch_size,m)]
      low_resol = x_lr[i*batch_size:min((i+1)*batch_size,m)]
      
      upscale_img = generator.predict(low_resol)
      
      real = np.ones(high_resol.shape[0]) - np.random.random_sample(high_resol.shape[0])*0.1
      fake = np.random.random_sample(low_resol.shape[0])*0.1

#       plt.show(upscale_img)
      dis_loss1 = discriminator.train_on_batch(x = high_resol,
                                         y = real)
      dis_loss2 = discriminator.train_on_batch(x = upscale_img,
                                    y = fake)
      
      dis_loss = (dis_loss1 + dis_loss2)*0.5
      
      dis_mean = dis_mean + dis_loss
      
      gan_loss = gans.train_on_batch(x = low_resol,
                                     y = [high_resol, real])
      gan_loss = gan_loss[0] + gan_loss[1]*1e-3
      
      gan_mean = gan_mean + gan_loss
      
      
      print('Epoch = '+str(epoch)+' batch = '+str(i)+' | discriminator loss = '+str(dis_loss)+' | gan loss = '+str(gan_loss))
    
    dis_mean = dis_mean/itera
    gan_mean = gan_mean/itera
    print('Epoch = '+str(epoch)+' | mean discriminator loss = '+str(dis_mean)+' | mean gan loss = '+str(gan_mean))
    tt1.append(dis_mean)
    tt2.append(gan_mean)
    print('------------------------------------------------Epoch '+str(epoch)+' complete-----------------------------------------------')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 96, 96, 64)   15616       ['input_1[0][0]']
#
#  p_re_lu (PReLU)                (None, 96, 96, 64)   64          ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 96, 96, 64)   36928       ['p_re_lu[0][0]']
#
#  batch_normalization (BatchNorm  (None, 96, 96, 64)  256         ['conv2d_1[0][0]']
#  alization)
#
#  p_re_lu_1 (PReLU)              (None, 96, 96, 64)   64          ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 96, 96, 64)   36928       ['p_re_lu_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 96, 96, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 96, 96, 64)   0           ['p_re_lu[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 96, 96, 64)   36928       ['add[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 96, 96, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  p_re_lu_2 (PReLU)              (None, 96, 96, 64)   64          ['batch_normalization_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 96, 96, 64)   36928       ['p_re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 96, 96, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 96, 96, 64)   0           ['add[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 96, 96, 64)   36928       ['add_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 96, 96, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  p_re_lu_3 (PReLU)              (None, 96, 96, 64)   64          ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 96, 96, 64)   36928       ['p_re_lu_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 96, 96, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 96, 96, 64)   0           ['add_1[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 96, 96, 64)   36928       ['add_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 96, 96, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  p_re_lu_4 (PReLU)              (None, 96, 96, 64)   64          ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 96, 96, 64)   36928       ['p_re_lu_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 96, 96, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 96, 96, 64)   0           ['add_2[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 96, 96, 64)   36928       ['add_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 96, 96, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  p_re_lu_5 (PReLU)              (None, 96, 96, 64)   64          ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_5[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 96, 96, 64)  256         ['conv2d_10[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 96, 96, 64)   0           ['add_3[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 96, 96, 64)   36928       ['add_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 96, 96, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  p_re_lu_6 (PReLU)              (None, 96, 96, 64)   64          ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_6[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 96, 96, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 96, 96, 64)   0           ['add_4[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 96, 96, 64)   36928       ['add_5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 96, 96, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  p_re_lu_7 (PReLU)              (None, 96, 96, 64)   64          ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_7[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 96, 96, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 96, 96, 64)   0           ['add_5[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 96, 96, 64)   36928       ['add_6[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 96, 96, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  p_re_lu_8 (PReLU)              (None, 96, 96, 64)   64          ['batch_normalization_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_8[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 96, 96, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 96, 96, 64)   0           ['add_6[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 96, 96, 64)   36928       ['add_7[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 96, 96, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  p_re_lu_9 (PReLU)              (None, 96, 96, 64)   64          ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_9[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 96, 96, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 96, 96, 64)   0           ['add_7[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 96, 96, 64)   36928       ['add_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 96, 96, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  p_re_lu_10 (PReLU)             (None, 96, 96, 64)   64          ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_10[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 96, 96, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 96, 96, 64)   0           ['add_8[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 96, 96, 64)   36928       ['add_9[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 96, 96, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  p_re_lu_11 (PReLU)             (None, 96, 96, 64)   64          ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_11[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 96, 96, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 96, 96, 64)   0           ['add_9[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 96, 96, 64)   36928       ['add_10[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 96, 96, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  p_re_lu_12 (PReLU)             (None, 96, 96, 64)   64          ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_12[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 96, 96, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 96, 96, 64)   0           ['add_10[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 96, 96, 64)   36928       ['add_11[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 96, 96, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  p_re_lu_13 (PReLU)             (None, 96, 96, 64)   64          ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_13[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 96, 96, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 96, 96, 64)   0           ['add_11[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 96, 96, 64)   36928       ['add_12[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 96, 96, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  p_re_lu_14 (PReLU)             (None, 96, 96, 64)   64          ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_14[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 96, 96, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 96, 96, 64)   0           ['add_12[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 96, 96, 64)   36928       ['add_13[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 96, 96, 64)  256         ['conv2d_29[0][0]']
#  ormalization)
#
#  p_re_lu_15 (PReLU)             (None, 96, 96, 64)   64          ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_15[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 96, 96, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 96, 96, 64)   0           ['add_13[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 96, 96, 64)   36928       ['add_14[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 96, 96, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  p_re_lu_16 (PReLU)             (None, 96, 96, 64)   64          ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 96, 96, 64)   36928       ['p_re_lu_16[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 96, 96, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 96, 96, 64)   0           ['add_14[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 96, 96, 64)   36928       ['add_15[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 96, 96, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 96, 96, 64)   0           ['p_re_lu[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 96, 96, 64)   36928       ['add_16[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 192, 192, 64  0           ['conv2d_34[0][0]']
#                                 )
#
#  p_re_lu_17 (PReLU)             (None, 192, 192, 64  64          ['up_sampling2d[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 192, 192, 64  36928       ['p_re_lu_17[0][0]']
#                                 )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 384, 384, 64  0          ['conv2d_35[0][0]']
#                                 )
#
#  p_re_lu_18 (PReLU)             (None, 384, 384, 64  64          ['up_sampling2d_1[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 384, 384, 3)  15555       ['p_re_lu_18[0][0]']
#
# ==================================================================================================
# Total params: 1,333,315
# Trainable params: 1,329,091
# Non-trainable params: 4,224
# __________________________________________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 384, 384, 3)]     0
#
#  conv2d_37 (Conv2D)          (None, 384, 384, 64)      1792
#
#  batch_normalization_33 (Bat  (None, 384, 384, 64)     256
#  chNormalization)
#
#  conv2d_38 (Conv2D)          (None, 384, 384, 64)      36928
#
#  batch_normalization_34 (Bat  (None, 384, 384, 64)     256
#  chNormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 384, 384, 64)      0
#
#  conv2d_39 (Conv2D)          (None, 384, 384, 128)     73856
#
#  batch_normalization_35 (Bat  (None, 384, 384, 128)    512
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 384, 384, 128)     0
#
#  conv2d_40 (Conv2D)          (None, 192, 192, 128)     147584
#
#  batch_normalization_36 (Bat  (None, 192, 192, 128)    512
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 192, 192, 128)     0
#
#  conv2d_41 (Conv2D)          (None, 96, 96, 256)       295168
#
#  batch_normalization_37 (Bat  (None, 96, 96, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 96, 96, 256)       0
#
#  conv2d_42 (Conv2D)          (None, 48, 48, 256)       590080
#
#  batch_normalization_38 (Bat  (None, 48, 48, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 48, 48, 256)       0
#
#  conv2d_43 (Conv2D)          (None, 24, 24, 512)       1180160
#
#  batch_normalization_39 (Bat  (None, 24, 24, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 24, 24, 512)       0
#
#  conv2d_44 (Conv2D)          (None, 12, 12, 512)       2359808
#
#  batch_normalization_40 (Bat  (None, 12, 12, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 12, 12, 512)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 100)               7372900
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 100)               0
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 12,066,057
# Trainable params: 12,062,217
# Non-trainable params: 3,840
# _________________________________________________________________
# None
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/structured_function.py:257: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# 1/1 [==============================] - 5s 5s/step

# %%
from tensorflow.keras.models import save_model

# Save the generator model
save_model(generator, 'generator_model.h5')

# %%
from tensorflow.keras.models import load_model

# Load the saved generator model
generator_model = load_model('generator_model.h5')

# %%
import glob
import numpy as np
from PIL import Image
from skimage.color import lab2rgb
import matplotlib.pyplot as plt

# Load the trained generator model
# generator_model = ...

# Load and preprocess a set of test images
test_image_paths = glob.glob('/kaggle/input/explo-deepak/explo/archive/Data/LR/10.png')

for test_image_path in test_image_paths:
    # Load the test image
    test_image = Image.open(test_image_path)
    
    # Preprocess the test image
    processed_test_image = test_image.resize((96,96), resample=Image.BICUBIC)
    processed_test_image = np.array(processed_test_image)
    processed_test_image = processed_test_image.astype(np.float32) / 255.0
    processed_test_image = np.expand_dims(processed_test_image, axis=0)
    
    # Generate a new image using the generator model
    generated_image = generator_model.predict(processed_test_image)
    
    # Convert the generated image to the correct data type and format
    generated_image = np.clip(generated_image, -1, 1)
    generated_image = ((generated_image + 1) / 2.0 * 255.0).astype(np.uint8)
    generated_image = np.squeeze(generated_image, axis=0)
    
#     generated_image = generated_image[..., :3]

    processed_test_image = np.squeeze(processed_test_image, axis=0)
    
#     generated_image = generated_image[..., ::-1]

    # Resize the generated image to match the original image dimensions
    generated_image = np.array(Image.fromarray(generated_image).resize((test_image.size[0], test_image.size[1]), resample=Image.BICUBIC))
    
    #print(processed_test_image[:,:,0:3].shape)
    print(generated_image.shape)
    # Convert the generated image from LAB color space to RGB color space
    generated_image_rgb = (generated_image)
    
#     generated_image_rgb = (generated_image[:,:,2:5])
    
#     generated_image_rgb = generated_image_rgb.convert('RGB')
    
#     generated_image_rgb = np.asarray(generated_image_rgb)
    
#     if generated_image_rgb.dtype != 'uint8':
#         generated_image_rgb = (generated_image_rgb*255).astype(np.uint8)
    
    # Display the original and generated images side by side
    fig, axs = plt.subplots(1, 2, figsize=(8, 4))
    axs[0].imshow(test_image)
    axs[0].set_title('Original Image')
    axs[1].imshow(generated_image_rgb)
    axs[1].set_title('Generated Image')
    plt.show()
#     Image.save(generated_image_rgb)
